# %% [markdown]
# ## Use the finetuned Local model for definition and wordplay

# %%
#!pip -q install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
#!pip -q install --no-deps "xformers<0.0.26" trl peft accelerate bitsandbytes

# %%
import os
from unsloth import FastLanguageModel
import torch

HFCOMPANY=os.environ.get("HFCOMPANY", "cryptic-wordplay-formalizer")

max_seq_length = 512
dtype = None
load_in_4bit = True
"DONE"

# %%
# find ~/.cache | grep transformed_definition_finder_model_3_epochs
#  ~/.cache/huggingface/hub/models--HFCOMPANY--transformed_definition_finder_model_3_epochs/blobs
model, tokenizer = None, None
def load_model_and_tokenizer(model_name, max_seq_len=max_seq_length):
  global model, tokenizer
  model, tokenizer = None, None

  model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = model_name,
    max_seq_length = max_seq_len,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
  )
  
  # https://www.reddit.com/r/LocalLLaMA/comments/1ar7e4m/comment/kqndd8k/
  #  .. https://github.com/unslothai/unsloth/blob/main/unsloth/models/loader.py#L187
  
  FastLanguageModel.for_inference(model) # Enable native 2x faster inference
  print(f"LOADED {tokenizer.eos_token_id=}")

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os, re

import time, datetime, pytz
tz = pytz.timezone('Asia/Singapore')

import numpy as np
#from solver.corpora import VectorEmbedder, CrosswordDictionary

# %%
from solver import llm
# Out:
# Redis server is available and running.

# %%
from solver.dataset import load_cryptonite_dataset, get_shuffled_idx

#data_train=load_cryptonite_dataset('train')
data_val  =load_cryptonite_dataset('val')
shuffled_idx_val = get_shuffled_idx(data_val, seed=42)

data_test =load_cryptonite_dataset('test')
shuffled_idx_test = get_shuffled_idx(data_test, seed=42)

len(shuffled_idx_test)
# Out:
# 26157

# %%
# Look at the crossword words dataset
from solver.corpora import CrosswordDictionary
crossword_dictionary = CrosswordDictionary(None)
print(len(crossword_dictionary.wordlist), crossword_dictionary.wordlist[0:100:10])
# Out:
# Loading as_lower_case=True embeddings took 0.0228s
# 304658 ['a', 'aaronical', 'abaca', 'abacuses', 'abalone', 'abandoning', 'abased', 'abashment', 'abating', 'abattoir']

# %% [markdown]
# ## Create definition and wordplay for all answer and alternative candidates
#
# * Example files:
#   + `./experiments/zero-shot/gemma2-9B_answer_guesser_3678_steps_resp-only/2024-09-06_13-37-15.log`
#     - 21.20% correct - 40.0% whole list
#   + `./experiments/zero-shot/gemma2-9B_answer_guesser_3678_steps_resp-only_t-1.0/2024-09-06_15-59-09.log`
#     - 15.90% correct - 48.20% whole list
#
#
# For each item in the given cryptonite run output (produced by 3_test_llm)
# * 'n' times for each
#   + Create a list of all answers found (including correct one)
#   * Generate a definition and wordplay from list

# %%
# Load up definitions+wordplay model
#model_name = f"./llama3-it_def_and_wordplay_guesser_4_epoch_noex" # local
model_name = f"./gemma2-9B_def-and-wordplay_guesser_4-epochs_resp-only" # local
load_model_and_tokenizer(model_name, max_seq_len=150)
#llm_prompt_style = llm.llama3_prompt  # With tricky prompting wrapping
llm_prompt_style = llm.alpaca_prompt

# %%
def log_file_name_wordplay(t, model_name, split='val'):  # stub='gemini'
  pth=f"./experiments/wordplay/{model_name.replace('/', '_')}"
  os.makedirs(pth, exist_ok=True)
  dt = time.strftime('%Y-%m-%d_%H-%M-%S', time.gmtime(t)) # Suitable for filename
  return f'{pth}/{split}_{dt}.log'

# %%
# Load up wordplay validation set
#from solver.dataset import get_wordplay_data_and_shuffle
#
#wordplay_val, shuffled_idx_wordplay_val = get_wordplay_data_and_shuffle('val')
#"DONE", shuffled_idx_wordplay_val[:5], len(shuffled_idx_wordplay_val)

# %%
def prompt_array_process_TXT_ONLY(arr, num_samples_per_answer, batch_size_max=10, 
                         temperature=0.5,):  # The arr will be split into these batches//num_samples to prevent OOMs
  batch_size = batch_size_max//num_samples_per_answer  # Must be an integer
  print(f"{batch_size_max=} {num_samples_per_answer=}")

  resp_accumulated=[]
  for start in range(0, len(arr), batch_size):
    last = min(start+batch_size, len(arr))

    #arr_batch=arr[start:last]
    # Build the array manually...
    arr_batch=[]
    for e in arr[start:last]:
      arr_batch += [ e for _ in range(num_samples_per_answer) ]

    inputs = tokenizer(arr_batch, return_tensors="pt", padding=True).to("cuda")  # All the prompts in one # , add_special_tokens=True
    #print(f"{start=} {last=} {batch_size=} {len(arr_batch)=} {inputs['input_ids'].shape=}") 
    prompt_length = inputs['input_ids'].shape[1]
  
    outputs = model.generate(**inputs, max_new_tokens=48, 
                             use_cache=True, pad_token_id=tokenizer.eos_token_id, 
                             #num_return_sequences=num_samples_per_answer, 
                             temperature=temperature, do_sample=True)
    #print(f"{outputs.shape=}") # torch.Size([20, 100])  :: 4*num_samples_per_answer, 100 tokens
    # Return only new(ish) tokens : Need to back off a little... (since 'definition: ' is in prompt)
    response_text_arr =  tokenizer.batch_decode(outputs[:, prompt_length-5:])
    
    for resp in response_text_arr: # Make this into a simpler list object, if it isn't one already
      resp_accumulated.append(resp) 
  return resp_accumulated

# %%
def prompt_array_process(arr, num_samples_per_answer, batch_size_max=10, 
                         temperature=0.5,):  # The arr will be split into these batches//num_samples to prevent OOMs
  batch_size = batch_size_max//num_samples_per_answer  # Must be an integer
  print(f"{batch_size_max=} {num_samples_per_answer=}")

  resp_accumulated=[]
  for start in range(0, len(arr), batch_size):
    last = min(start+batch_size, len(arr))
    
    # Build the array manually...
    arr_batch=[]
    for e in arr[start:last]:
      arr_batch += [ e for _ in range(num_samples_per_answer) ]

    inputs = tokenizer(arr_batch, return_tensors="pt", padding=True).to("cuda")  # All the prompts in one # , add_special_tokens=True
    #print(f"{start=} {last=} {batch_size=} {len(arr_batch)=} {inputs['input_ids'].shape=}") 
    prompt_length = inputs['input_ids'].shape[1]
  
    output_stuff = model.generate(**inputs, max_new_tokens=48, 
                             use_cache=True, pad_token_id=tokenizer.eos_token_id, 
                             #num_return_sequences=num_samples_per_answer, 
                             temperature=temperature, do_sample=True,
                             return_dict_in_generate=True,   # New line here 
                             output_scores=True,  # New line here - see 3_test_llm for detailed debugging
                          )
    # Return only new(ish) tokens : Need to back off a little... (since 'definition: ' is in prompt)
    outputs = output_stuff['sequences']
    response_text_arr =  tokenizer.batch_decode(outputs[:, prompt_length-5:])
    
    for response_idx, response_text in enumerate(response_text_arr):
      logprobs = []
      with torch.no_grad():
        for timestep, scores in enumerate(output_stuff.scores):
          response_timestep_scores = scores[response_idx]  # This is the scores (~logits) for this timestep
          #print(f"{response_timestep_scores.shape=}")
          response_timestep_logprobs = torch.log_softmax(response_timestep_scores, dim=-1)
          output_token = outputs[response_idx, prompt_length+timestep]
          logprobs.append( response_timestep_logprobs[output_token].item() )
          if output_token==1: 
            #print(f"Got <eos> at {timestep=}")
            break # This is <eos>
      response_logprob = sum(logprobs) / len(logprobs)
      
      resp_accumulated.append( (response_text, response_logprob) ) 
  return resp_accumulated

# %%
import solver.dataset
def get_def_and_wordplay_responses(data_item, candidates_arr, 
                                   only_valid_answers=True,
                                   num_samples_per_answer=10, temperature=0.5,
                                   flog=None):
  clue = data_item['clue']
  pattern = data_item['enumeration'].replace('(', '').replace(')', '')
  clue_with_def = clue.replace( f"({pattern})", "").strip()   # Need to take off the pattern...
  clue_no_def   = clue_with_def.replace('{','').replace('}','').strip()
  answer_gold = data_item['answer'].upper()  # This is the ground-truth answer
  #answer_gold_added=False
  
  answers = set(candidates_arr)
  if only_valid_answers:  # Filter non-crossword answers
    answers = set([ answer for answer in answers if crossword_dictionary.includes(answer, split_phrase=True) ])

  if answer_gold not in answers:
    answers.add(answer_gold)

  def eot_truncate(ans, eot):
    if eot in ans:
      pos = ans.index(eot)
      ans = ans[:pos]
    return ans
  
  prompt_arr, answer_arr = [], []
  for answer_candidate in sorted(list(answers)):
    prompts = llm.prompt_def_and_wordplay_guesser(llm_prompt_style, clue_no_def, answer_candidate, '') # No definition or wordplay given
    prompt_arr.append( prompts['prompt_test'] )
    answer_arr.append(answer_candidate) 
 
  response_tuple_arr = prompt_array_process(prompt_arr, num_samples_per_answer, temperature=temperature)
  
  responses=[]
  for resp_idx, (response_text, response_logprob) in enumerate(response_tuple_arr):
    # Order for the multiple samples is p1,p1,p1,p1,p1, p2,p2,p2,p2,p2, p3,p3,p3,p3,p3, ...
    prompt_idx = resp_idx//num_samples_per_answer
    answer_candidate = answer_arr[prompt_idx]
    fields, count_found, finished = { 'definition:':None, 'wordplay:':None, }, 0, False
    for line in response_text.split('\n'):
      line = line.strip()
      for k,v in fields.items():
        if line.startswith(k) and v is None:
          ans = line[len(k):].strip()
          ans = eot_truncate(ans, '<|end_of_text|>')
          ans = eot_truncate(ans, '<|eot_id|>')
          fields[k]=ans.strip()
          count_found+=1
          if count_found==len(fields):
            finished=True
          break
      if finished:
        break

    is_gold=(answer_candidate==answer_gold)
    freq = sum([1 for candidate in candidates_arr if answer_candidate==candidate])  # Count up frequency in original
    responses.append( dict(
      answer=answer_candidate, freq=freq,
      clue_with_def=fields['definition:'], 
      wordplay=fields['wordplay:'],
      logprob=response_logprob,
    ))
  
    if flog is not None:
      flog.write('\n---PROMPT---\n')
      flog.write(prompt_arr[prompt_idx])
      flog.write('\n---RESPONSE---\n')
      flog.write(response_text)
      solver.dataset.write_log_result(flog, data_item['idx_shuffled'], data_item['idx_orig'], dict(
        clue=clue_no_def, pattern=pattern,
        answer=answer_candidate, is_gold=is_gold, freq=freq,
        #answer_gold_added = answer_gold_added,  # This is *OLD*
        clue_with_def=fields['definition:'], 
        wordplay=fields['wordplay:'],
        logprob=response_logprob,
      ))
 
  return responses

# %%
if True:  # Check 1 full example with some wrong candidates
  idx=14
  #data_item = data_test[shuffled_idx_test[idx]]
  data_item = data_val[shuffled_idx_val[idx]]
  t0=time.time()
  responses = get_def_and_wordplay_responses(data_item, ['TROTSKY','ANIMAL','EXPERIMENT'], ) # num_samples_per_answer=5,
  #responses = get_def_and_wordplay_responses(data_item, [], num_samples_per_answer=5,)
  #print(len(responses))
  for fields in responses:
    print(f"""    answer: '{ fields["answer"] }', freq={fields["freq"]}""" )  
    print(f"""definition: '{ fields["clue_with_def"] }'""" )  
    print(f"""  wordplay: '{ fields["wordplay"] }'""" )  
    print(f"""   logprob: { fields["logprob"]:.4f}""" )  
  print(f"""answer_gold: '{ data_item["answer"].upper() }' : elapsed:{(time.time()-t0):.3f}sec""" )

# %%
t0=time.time()

def multiple_answers_for_whole_llm_answer_log(flog_arr, data_set, shuffled_idx, valid_responses_max=20, flog=None):
  overlaid = solver.dataset.read_log_results(flog_arr)
  
  pos, cnt, examples = 0, 0, len(overlaid)
  for idx, model_outputs in overlaid.items():
    data_item = data_set[shuffled_idx[idx]]  
    
    model_data = model_outputs[0]
    model_answers=model_data['answers_valid'][:valid_responses_max]
    #print(f"{idx:4d} : {len(model_answers)=}")
    #continue
    if model_data['idx_orig']!=shuffled_idx[idx]:
      print(f"FAILURE : {model_data['idx_orig']=} != {shuffled_idx[idx]=}")
      return # A FAILURE
    responses = get_def_and_wordplay_responses(data_item, model_answers, flog=flog)
    cnt+=1
    
    elapsed=(time.time()-t0)
    remaining=elapsed/cnt*(examples-cnt)
    eta_local = datetime.datetime.now(tz)+datetime.timedelta(seconds=remaining)
    print(f"@{idx:4d}/{examples:4d} ({elapsed/cnt:5.2f}s/iter ETA:{eta_local.strftime('%Y-%m-%d %H:%M:%S %Z')})")
    #if cnt>=10: break

# NB: test set...
log_file = log_file_name_wordplay(t0, model_name, split='test')  # This is for our output
with open(log_file, 'a') as flog:
  multiple_answers_for_whole_llm_answer_log([
    './experiments/zero-shot/gemma2-9B_answer_guesser_3678_steps_resp-only_t-1.0/2024-09-06_15-59-09.log',
  ], data_set=data_test, shuffled_idx=shuffled_idx_test, flog=flog, )

# NB: validation set...
#log_file = log_file_name_wordplay(t0, model_name, split='val')  # This is for our output
#with open(log_file, 'a') as flog:
#  multiple_answers_for_whole_llm_answer_log([
#    './experiments/zero-shot/gemma2-9B_answer_guesser_3678_steps_resp-only_t-1.0/2024-09-26_05-20-39.log', # *val* 21.70% correct
#  ], data_set=data_val, shuffled_idx=shuffled_idx_val, flog=flog, )
  
print(f"DONE : '{log_file}'") 

# PREVIOUS : Takes ~1h20m for 282 examples in val (only need 100, though...)
# Takes ~4hr for 1000 examples (each with up to 20 candidates) in test log file (5 samples each)
# Takes ~?hr for 1000 examples (each with up to 20 candidates, all valid, with freq) in test log file (10 samples each)
# Start = 12:35

# %%
print(f"DONE : '{log_file}'") 
# This: './experiments/zero-shot/gemma2-9B_answer_guesser_3678_steps_resp-only_t-1.0/2024-09-06_15-59-09.log',
#  leads to :
# DONE : './experiments/wordplay/._gemma2-9B_def-and-wordplay_guesser_4-epochs_resp-only/test_2024-09-23_05-35-16.log'

# This val : './experiments/zero-shot/gemma2-9B_answer_guesser_3678_steps_resp-only_t-1.0/2024-09-26_05-20-39.log', # *val* 21.70% correct
#  leads to :
# DONE : './experiments/wordplay/._gemma2-9B_def-and-wordplay_guesser_4-epochs_resp-only/val_2024-09-26_07-39-07.log'

# %%
PAUSE

# %% [markdown]
# ### "dumb ranker" : Does logprob choice work?

# %%
import solver.dataset
wordplays_found_val = solver.dataset.read_log_results([
  # dumb wordplay reranker... (val)
  './experiments/wordplay/._gemma2-9B_def-and-wordplay_guesser_4-epochs_resp-only/val_2024-11-27_09-54-18.log',
])
wordplays_found_test = solver.dataset.read_log_results([
  # dumb wordplay reranker... (test)
  './experiments/wordplay/._gemma2-9B_def-and-wordplay_guesser_4-epochs_resp-only/test_2024-11-27_13-28-35.log',
])

len(wordplays_found_val), len(wordplays_found_test)  # Each entry has an array of result dicts in it...
# Out:
# (262, 235)

# %%
wordplays_found_val[0][0:30:12]
# Out:
# [{'answer': 'BLUEBOTTLE',
#   'clue': 'little bird to dart across sill',
#   'clue_with_def': '{little bird} to dart across sill',
#   'freq': 8,
#   'is_gold': False,
#   'logprob': -0.27678545117378234,
#   'pattern': '10',
#   'wordplay': 'BENT = to dart, reversed = NETB, inside BLUE = sad, low, down, as in a blue mood.',
#   'idx_orig': 8116},
#  {'answer': 'FLEDGELING',
#   'clue': 'little bird to dart across sill',
#   'clue_with_def': '{little bird} to dart across sill',
#   'freq': 0,
#   'is_gold': True,
#   'logprob': -0.1702921748161316,
#   'pattern': '10',
#   'wordplay': 'FLEE = dart, insert D(G) and add IN(G).',
#   'idx_orig': 8116},
#  {'answer': 'FLIPPANTLY',
#   'clue': 'little bird to dart across sill',
#   'clue_with_def': 'little bird to dart across sill {flippantly}',
#   'freq': 2,
#   'is_gold': False,
#   'logprob': -0.033895536831447054,
#   'pattern': '10',
#   'wordplay': 'FLIP (little bird) PANT (to dart) insert LY (across sill).',
#   'idx_orig': 8116}]

# %%
# Calculate accuracy across all questions
def calculate_accuracy_via_logprob(wordplays, questions_max=200, data_set=None, shuffled_idx=None, 
                                   include_non_suggested_gold=False, ):
  cnt, pos,  = 0,0
  pos_q, cnt_q = 0, 0  # Quick (not hard)
  for question_idx in range(0, questions_max):
    wordplay_arr=wordplays[question_idx]

    answer_logprob_arr, gold_answer = [], None
    for w in wordplay_arr:
      if w['is_gold']:
        gold_answer = w['answer']
        gold_answer_val = w['logprob']
      if w['freq']==0 and not include_non_suggested_gold:
        continue # Skip the freq=0 entry for accuracy calculations
      answer_logprob_arr.append( ( w['answer'], w['logprob'] ) )
      
    if len(answer_logprob_arr)>0:
      answer_logprob_arr = sorted(answer_logprob_arr, key=lambda answer_logprob: -answer_logprob[1])
      answer_logprob_best = answer_logprob_arr[0]  # Highest logprob, 
      answer_logprob, answer_logprob_val = answer_logprob_best  # un-tuple the pair
    else:
      #print(wordplay_arr)
      # Even though we may have been told the gold one, we didn't manage any guesses of our own...
      answer_logprob="FAILED-TO-GUESS-ANYTHING"
      answer_logprob_val=-999
        
    if gold_answer is not None: 
      # Skip printing the ones without an answer in the list of possibilities (we definitely would get this wrong)
      print(f"{question_idx:4d} : {gold_answer_val:.4f} : {gold_answer=:>20s} vs {answer_logprob:20s} : {answer_logprob_val:.4f}")
      
    model_answer = answer_logprob

    correct = model_answer==gold_answer

    is_quick=False
    if shuffled_idx is not None:
      data_item = data_set[shuffled_idx[question_idx]]
      if gold_answer is not None and data_item['answer'].upper() != gold_answer:
        raise("Mismatch of val vs test cryptonite reference")
      is_quick = data_item['quick']
      if False:
        if is_quick: 
          print("QUICK::", model_answer, gold_answer)
        else: 
          print("HARD ::", model_answer, gold_answer)
      
    if correct: pos+=1
    cnt+=1
    if is_quick:
      if correct: pos_q+=1
      cnt_q+=1
  #print(f"{pos/cnt*100.:.2f}%")
  print(f"Overall : {pos:4d}/{cnt:4d} correct={100.*pos/cnt:5.2f}%")
  if cnt_q>0: 
    print(f"  Quick : {pos_q:4d}/{cnt_q:4d} correct={100.*pos_q/cnt_q:5.2f}%")
  print(f"   Hard : {pos-pos_q:4d}/{cnt-cnt_q:4d} correct={100.*(pos-pos_q)/(cnt-cnt_q):5.2f}%")
  
  return pos, cnt
  
calculate_accuracy_via_logprob(wordplays_found_val,  data_set=data_val, shuffled_idx=shuffled_idx_val, )
calculate_accuracy_via_logprob(wordplays_found_test, data_set=data_test, shuffled_idx=shuffled_idx_test, )
# Out:
#    0 : -0.0584 : gold_answer=          FLEDGELING vs GOLDCRESTS           : -0.0011
#    1 : -0.0358 : gold_answer=                AVON vs SERE                 : -0.0091
#    2 : -0.1552 : gold_answer=             LAMPOON vs ASSAULT              : -0.0155
#    3 : -0.0036 : gold_answer=               COPSE vs COPSE                : -0.0036
#    4 : -0.0764 : gold_answer=    BURY THE HATCHET vs THAW THE CHEDDAR     : -0.0056
#    5 : -0.2839 : gold_answer=                 PIT vs PIT                  : -0.1143
#    6 : -0.0024 : gold_answer=             ARCADIA vs ARCADIA              : -0.0024
#    7 : -0.1590 : gold_answer=            STRAINED vs EMBRACED             : -0.0236
#    8 : -0.1657 : gold_answer=           STERNWARD vs REARRANGE            : -0.0216
#    9 : -0.1920 : gold_answer=                THUS vs MONK                 : -0.0229
#   10 : -0.0801 : gold_answer=               VIPER vs VIRGO                : -0.0236
#   11 : -0.0373 : gold_answer=              BONNET vs BONNET               : -0.0373
#   12 : -0.1148 : gold_answer=      DOUBLE CROSSES vs CARPET BAGGAGE       : -0.0375
#   13 : -0.1253 : gold_answer=             ESTONIA vs AIRPORT              : -0.0014
#   14 : -0.0957 : gold_answer=           CENTURION vs OUTRUNNER            : -0.0766
#   15 : -0.1430 : gold_answer=           UNCLASPED vs UNBUTTONS            : -0.0199
#   16 : -0.0286 : gold_answer=               HERON vs HERON                : -0.0286
#   17 : -0.0363 : gold_answer=              OSIRIS vs ABLOOM               : -0.0012
#   18 : -0.4953 : gold_answer=       CHRISTMAS EVE vs CHRISTMAS DAY        : -0.0259
#   19 : -0.2365 : gold_answer=               FALSE vs EATEN                : -0.0031
#   20 : -0.0015 : gold_answer=            SALVAGES vs SAVIOURS             : -0.0486
#   21 : -0.0256 : gold_answer=          IN GENERAL vs IN GENERAL           : -0.0256
#   22 : -0.0244 : gold_answer=         BROWN STUDY vs HEAVY HEART          : -0.0489
#   23 : -0.0662 : gold_answer=               HYENA vs LARGO                : -0.0148
#   24 : -0.1877 : gold_answer=              SOLELY vs FAILED-TO-GUESS-ANYTHING : -999.0000
#   25 : -0.0278 : gold_answer=                 BAN vs BAN                  : -0.0278
#   26 : -0.0153 : gold_answer=          BAIN MARIE vs FISH FRYER           : -0.0106
#   27 : -0.0195 : gold_answer=               POSER vs NUDGE                : -0.0178
#   28 : -0.1244 : gold_answer=            DESELECT vs DELUSION             : -0.0325
#   29 : -0.0862 : gold_answer=          JOE BLOGGS vs CUE JETSAM           : -0.0516
#   30 : -0.1193 : gold_answer=        MEMENTO MORI vs POSTERN GATE         : -0.0116
#   31 : -0.0684 : gold_answer=             TROTTER vs FASTISH              : -0.0011
#   32 : -0.0183 : gold_answer=          MARIONETTE vs HANGGLIDER           : -0.0236
#   33 : -0.0328 : gold_answer=    ENGLISH LANGUAGE vs ENGLISH LANGUAGE     : -0.0328
#   34 : -0.0027 : gold_answer=              DEPEND vs NUMBER               : -0.0083
#   35 : -0.0825 : gold_answer=            MIDDLE C vs MIDDLE C             : -0.0464
#   36 : -0.2243 : gold_answer=           SLINGBACK vs SLINGBACK            : -0.0008
#   37 : -0.0384 : gold_answer=          KIRBY GRIP vs PINCH BARK           : -0.0406
#   38 : -0.0970 : gold_answer=               STAIN vs DOTER                : -0.0373
#   39 : -0.1604 : gold_answer=             SCRATCH vs STOMACH              : -0.0207
#   40 : -0.0132 : gold_answer=              CAVORT vs CAVORT               : -0.0132
#   41 : -0.0497 : gold_answer=           SPECIALLY vs MICROSOME            : -0.0614
#   42 : -0.2030 : gold_answer=          ANNIE HALL vs ROYAL HALL           : -0.0306
#   43 : -0.2055 : gold_answer=          FUNNEL WEB vs GULLET NET           : -0.0143
#   44 : -0.0611 : gold_answer=             EPISTLE vs SQUALID              : -0.0621
#   45 : -0.0562 : gold_answer=             DEPOSIT vs CASSINO              : -0.0277
#   46 : -0.0650 : gold_answer=             PALMYRA vs PALMYRA              : -0.0495
#   47 : -0.0224 : gold_answer=            BERATING vs SCOLDING             : -0.0150
#   48 : -0.1134 : gold_answer=             EYEWASH vs TWADDLE              : -0.0602
#   49 : -0.0144 : gold_answer=                FLAT vs LAIN                 : -0.0172
#   50 : -0.2298 : gold_answer=               SCRUB vs FAGOT                : -0.0209
#   51 : -0.0376 : gold_answer=               FLOOD vs TAPER                : -0.0308
#   52 : -0.0037 : gold_answer=          BREAKDOWNS vs DISPIRITED           : -0.0137
#   53 : -0.1413 : gold_answer=             SCHMUCK vs AIRHEAD              : -0.0567
#   54 : -0.0320 : gold_answer=            TRAVESTY vs AIRBORNE             : -0.0398
#   55 : -0.0319 : gold_answer=             HYDRANT vs HEADSET              : -0.0242
#   56 : -0.0624 : gold_answer=            ANALYSIS vs ANALYSIS             : -0.0176
#   57 : -0.0064 : gold_answer=    MONEY LAUNDERING vs MONEY LAUNDERING     : -0.0064
#   58 : -0.1142 : gold_answer=           BLACK OUT vs CLEAR OUT            : -0.0070
#   59 : -0.0268 : gold_answer=            SINISTER vs RESISTED             : -0.0034
#   60 : -0.0145 : gold_answer=           MARMALADE vs ASSEMBLED            : -0.0191
#   61 : -0.0032 : gold_answer=           PROJECTED vs MANIFESTS            : -0.0102
#   62 : -0.1358 : gold_answer=            INCLINED vs UNBEATEN             : -0.0030
#   63 : -0.0090 : gold_answer=                SWIM vs SWIM                 : -0.0090
#   64 : -0.1400 : gold_answer=       PERFECT PITCH vs BOWLING ALLEY        : -0.0336
#   65 : -0.1253 : gold_answer=                SODA vs DODO                 : -0.0288
#   66 : -0.3849 : gold_answer=               XHOSA vs OMAHA                : -0.0059
#   67 : -0.0373 : gold_answer=               HEIRS vs HEIRS                : -0.0373
#   68 : -0.1748 : gold_answer=         LOOSESTRIFE vs FAILED-TO-GUESS-ANYTHING : -999.0000
#   69 : -0.2367 : gold_answer=              SCRAPE vs SCRIBE               : -0.0613
#   70 : -0.2469 : gold_answer=             IGNORED vs OUTCAST              : -0.0628
#   71 : -0.1135 : gold_answer=                 BAN vs BAR                  : -0.0288
#   72 : -0.4903 : gold_answer=            POTATION vs SPRITZER             : -0.0078
#   73 : -0.1380 : gold_answer=               SELLS vs FAILED-TO-GUESS-ANYTHING : -999.0000
#   74 : -0.0920 : gold_answer=               OSTIA vs TYROL                : -0.0634
#   75 : -0.0212 : gold_answer=          PROSTRATED vs PROSTRATED           : -0.0212
#   76 : -0.0030 : gold_answer=           MECHANICS vs MECHANICS            : -0.0030
#   77 : -0.1075 : gold_answer=               COPSE vs TEENY                : -0.0030
#   78 : -0.0606 : gold_answer=          PRIORITISE vs ADJUDICATE           : -0.0107
#   79 : -0.0738 : gold_answer=          LOSE HEART vs HOPE CHEST           : -0.0190
#   80 : -0.0507 : gold_answer=             EXPRESS vs ELEMENT              : -0.0238
#   81 : -0.0615 : gold_answer=             BREAKER vs SCATTER              : -0.0351
#   82 : -0.0771 : gold_answer=            PLANKTON vs MERCHANT             : -0.0696
#   83 : -0.1114 : gold_answer=              PEANUT vs NICKEL               : -0.0118
#   84 : -0.1198 : gold_answer=               ESSEN vs TURIN                : -0.0149
#   85 : -0.0171 : gold_answer=               RISER vs STAIR                : -0.0450
#   86 : -0.0507 : gold_answer=           OCTOPUSSY vs CUSTODIAN            : -0.0156
#   87 : -0.0598 : gold_answer=        COLLABORATOR vs CONFISCATORY         : -0.0297
#   88 : -0.1484 : gold_answer=              SPLICE vs GATHER               : -0.0381
#   89 : -0.3218 : gold_answer=               ISAAC vs JACOB                : -0.0807
#   90 : -0.0062 : gold_answer=         CRAPSHOOTER vs SPORTSWOMAN          : -0.0394
#   91 : -0.0937 : gold_answer=                MEMO vs PROM                 : -0.0406
#   92 : -0.0184 : gold_answer=             SUMMERY vs HOTHEAD              : -0.0349
#   93 : -0.0304 : gold_answer=         MARTIAL LAW vs MARTIAL LAW          : -0.0304
#   94 : -0.0730 : gold_answer=               ISSEI vs INSET                : -0.0197
#   95 : -0.1647 : gold_answer=            INACTION vs INACTION             : -0.0032
#   96 : -0.1702 : gold_answer=                EARN vs CITE                 : -0.0836
#   97 : -0.1925 : gold_answer=              ENNEAD vs ANYHOW               : -0.0012
#   98 : -0.2378 : gold_answer=              SHERPA vs STEERS               : -0.0256
#   99 : -0.1846 : gold_answer=               SPOIL vs PUMPS                : -0.0486
#  100 : -0.0068 : gold_answer=              SAVOUR vs SAVOUR               : -0.0068
#  101 : -0.0734 : gold_answer=               OSTIA vs GENOA                : -0.0708
#  102 : -0.0838 : gold_answer=           CHAMPAGNE vs CHAMPAGNE            : -0.0632
#  103 : -0.1227 : gold_answer=              OUSTER vs OUSTED               : -0.0399
#  104 : -0.0905 : gold_answer=               USING vs LASER                : -0.0624
#  105 : -0.0847 : gold_answer=           HOPSCOTCH vs SCRAMBLER            : -0.0503
#  106 : -0.0603 : gold_answer=             DEPOSIT vs SILENCE              : -0.0325
#  107 : -0.0283 : gold_answer=              SCRAPE vs REDEEM               : -0.0169
#  108 : -0.0345 : gold_answer=        COUNTERPOISE vs TRAILBLAZERS         : -0.0212
#  109 : -0.0079 : gold_answer=              OUTCRY vs OUTCRY               : -0.0079
#  110 : -0.0585 : gold_answer=          PLASTICINE vs PLASTICINE           : -0.0490
#  111 : -0.0695 : gold_answer=           HOPSCOTCH vs QUADRILLE            : -0.0153
#  112 : -0.0515 : gold_answer=        WISHING WELL vs BENEFIT FOND         : -0.0098
#  113 : -0.0070 : gold_answer=          ORIGINALLY vs ORIGINALLY           : -0.0070
#  114 : -0.0328 : gold_answer=               RHODA vs SUSAN                : -0.0155
#  115 : -0.0360 : gold_answer=               CLANG vs CLINK                : -0.0111
#  116 : -0.0269 : gold_answer=            GIGANTIC vs INDICATE             : -0.0494
#  117 : -0.0824 : gold_answer=          BILLY GOAT vs GREEN LEAF           : -0.0501
#  118 : -0.4892 : gold_answer=            MAHARAJA vs ALBERICH             : -0.0507
#  119 : -0.0255 : gold_answer=             JEZEBEL vs JEZEBEL              : -0.0255
#  120 : -0.1187 : gold_answer=                REED vs BENT                 : -0.0213
#  121 : -0.1080 : gold_answer=                 KIP vs NAP                  : -0.0435
#  122 : -0.0243 : gold_answer=             NEUTRAL vs FAILED-TO-GUESS-ANYTHING : -999.0000
#  123 : -0.0596 : gold_answer=               EVENT vs FEATS                : -0.0090
#  124 : -0.1311 : gold_answer=               EVENT vs EVENT                : -0.0139
#  125 : -0.1184 : gold_answer=        TOUCH AND GO vs TOUCH AND GO         : -0.0720
#  126 : -0.0821 : gold_answer=              BISHOP vs HOMBRE               : -0.0133
#  127 : -0.0127 : gold_answer=      ACCOMPLISHMENT vs ACCOMPLISHMENT       : -0.0127
#  128 : -0.0802 : gold_answer=               STAIN vs TAINT                : -0.0406
#  129 : -0.0829 : gold_answer=                LISP vs PLEA                 : -0.0309
#  130 : -0.0067 : gold_answer=            SPACEMAN vs STRANDED             : -0.0080
#  131 : -0.2769 : gold_answer=               CREAM vs CREME                : -0.0317
#  132 : -0.0350 : gold_answer=              DURBAN vs CALIPH               : -0.0591
#  133 : -0.1757 : gold_answer=         CHECKED OUT vs CHEATED OUT          : -0.0280
#  134 : -0.0015 : gold_answer=          CATTLE PEN vs ANIMAL PEN           : -0.0015
#  135 : -0.0691 : gold_answer=               TAROT vs CHESS                : -0.0045
#  136 : -0.1092 : gold_answer=         WEASEL WORD vs DOUBLE OATH          : -0.0290
#  137 : -0.0299 : gold_answer=               SCRUB vs DWARF                : -0.0139
#  138 : -0.0138 : gold_answer=               EVENT vs EVENT                : -0.0138
#  139 : -0.0051 : gold_answer=                 LOO vs LAD                  : -0.0325
#  140 : -0.0085 : gold_answer=         VINTAGE CAR vs COCKPIT BAR          : -0.0039
#  141 : -0.0107 : gold_answer=              SCALES vs STEELS               : -0.0065
#  142 : -0.2546 : gold_answer=         INTENSIFIER vs BARBAROUSLY          : -0.0361
#  143 : -0.0756 : gold_answer=            DRESSING vs DRESSING             : -0.0304
#  144 : -0.0337 : gold_answer=          TENDERLOIN vs TENDERLOIN           : -0.0337
#  145 : -0.0016 : gold_answer=             ALFREDA vs ALFREDA              : -0.0016
#  146 : -0.0669 : gold_answer=              SCOFFS vs TEASES               : -0.0378
#  147 : -0.0430 : gold_answer=         LOUTISHNESS vs UNMANLINESS          : -0.0109
#  148 : -0.1008 : gold_answer=             PALADIN vs EARLDOM              : -0.0440
#  149 : -0.0103 : gold_answer=            STUFFING vs DRESSING             : -0.0242
#  150 : -0.0234 : gold_answer=             TEEMING vs NEMESIS              : -0.0162
#  151 : -0.0175 : gold_answer=              POMONA vs TARTAR               : -0.0335
#  152 : -0.0615 : gold_answer=              ENSURE vs ATTEST               : -0.0225
#  153 : -0.0426 : gold_answer=             ELASTIC vs TENSILE              : -0.0221
#  154 : -0.0671 : gold_answer=              EQUIPE vs EQUIPE               : -0.0671
#  155 : -0.0215 : gold_answer=              RACKET vs BEDLAM               : -0.0430
#  156 : -0.0322 : gold_answer=          MARIONETTE vs TAMBOURINE           : -0.0092
#  157 : -0.0309 : gold_answer=            ELEVENTH vs MIDNIGHT             : -0.0009
#  158 : -0.0201 : gold_answer=          IMPORTANCE vs FAILED-TO-GUESS-ANYTHING : -999.0000
#  159 : -0.0665 : gold_answer=          DEADLY SIN vs BOTTOM OUT           : -0.0415
#  160 : -0.0905 : gold_answer=             STREETS vs AIRPORT              : -0.0061
#  161 : -0.1669 : gold_answer=             ECLAIRS vs MUFFINS              : -0.0719
#  162 : -0.0226 : gold_answer=  ARMED TO THE TEETH vs READY TO THE TEETH   : -0.0251
#  163 : -0.0084 : gold_answer=                NUTS vs SOYA                 : -0.0164
#  164 : -0.3021 : gold_answer=            RAILLERY vs TEASINGS             : -0.0082
#  165 : -0.0251 : gold_answer=                 REF vs DIP                  : -0.0206
#  166 : -0.1419 : gold_answer=             BELLINI vs HOLBEIN              : -0.0816
#  167 : -0.0016 : gold_answer=             SINGLET vs SINGLET              : -0.0016
#  168 : -0.2797 : gold_answer=            OUTSIDER vs OUTCASTE             : -0.0046
#  169 : -0.0778 : gold_answer=             COHABIT vs OVERLAP              : -0.0475
#  170 : -0.0030 : gold_answer=          MOTIONLESS vs SPEECHLESS           : -0.0032
#  171 : -0.1749 : gold_answer=             CLOBBER vs CHASSIS              : -0.0346
#  172 : -0.1587 : gold_answer=           SHRINKAGE vs SHRINKAGE            : -0.0131
#  173 : -0.0458 : gold_answer=              DAPPER vs DEEJAY               : -0.0593
#  174 : -0.1606 : gold_answer=              SIESTA vs ROOSTS               : -0.0508
#  175 : -0.0214 : gold_answer=           TALK DOWN vs CAST DOWN            : -0.0100
#  176 : -0.0113 : gold_answer=             PALADIN vs FAILED-TO-GUESS-ANYTHING : -999.0000
#  177 : -0.0125 : gold_answer=               HADES vs DEPTH                : -0.0787
#  178 : -0.0697 : gold_answer=              SUPINE vs BEHIND               : -0.0341
#  179 : -0.0208 : gold_answer=             GALLEON vs STEAMER              : -0.0163
#  180 : -0.1575 : gold_answer=               CLAIM vs EXACT                : -0.0199
#  181 : -0.0044 : gold_answer=           LEAVE OFF vs LEAVE OUT            : -0.0013
#  182 : -0.0468 : gold_answer=            ALI BABA vs TWO TIME             : -0.0516
#  183 : -0.1202 : gold_answer=            INACTION vs INACTION             : -0.0256
#  184 : -0.0476 : gold_answer= THE WAY WE LIVE NOW vs THE WAY WE LIVE NOW  : -0.0476
#  185 : -0.1765 : gold_answer=     CHRISTMAS CAROL vs CHRISTMAS CAROL      : -0.0195
#  186 : -0.0051 : gold_answer=             NEUTRAL vs RETREAT              : -0.0048
#  187 : -0.0662 : gold_answer=           CANONISED vs MONKSHOOD            : -0.0224
#  188 : -0.1194 : gold_answer=              CAMPUS vs ONWARD               : -0.0001
#  189 : -0.1197 : gold_answer=          MEADOW RUE vs WREATH RUE           : -0.0070
#  190 : -0.2769 : gold_answer=               NOOSE vs LATER                : -0.0345
#  191 : -0.0763 : gold_answer=           BLUE EYED vs HELD DEEM            : -0.0100
#  192 : -0.0476 : gold_answer=            REVISITS vs REVISITS             : -0.0476
#  193 : -0.1784 : gold_answer=          ORANG UTAN vs GREAT APES           : -0.0606
#  194 : -0.0265 : gold_answer=          MOTIONLESS vs MOTIONLESS           : -0.0265
#  195 : -0.1014 : gold_answer=              BREWED vs CHALET               : -0.0570
#  196 : -0.0280 : gold_answer=           SPARTACUS vs SPARTACUS            : -0.0280
#  197 : -0.3476 : gold_answer=           BONAPARTE vs OMBUDSMAN            : -0.0047
#  198 : -0.1380 : gold_answer=            TRAVESTY vs TITMOUSE             : -0.0612
#  199 : -0.0161 : gold_answer=          NEIGHBOURS vs BLUEBOTTLE           : -0.0253
# Overall :   42/ 200 correct=21.00%
#   Quick :    2/  13 correct=15.38%
#    Hard :   40/ 187 correct=21.39%
#    0 : -0.2091 : gold_answer=             ETONIAN vs BOWKNOT              : -0.0329
#    1 : -0.0094 : gold_answer=    BOIS DE BOULOGNE vs BUTT IN GRENOBLE     : -0.0126
#    2 : -0.0245 : gold_answer=             RIDDLES vs GRIDDLE              : -0.0054
#    3 : -0.3286 : gold_answer=             NONSTOP vs OUTPOUR              : -0.0269
#    4 : -0.1641 : gold_answer=            LONG AGO vs GONE DRY             : -0.0228
#    5 : -0.2241 : gold_answer=                FLEW vs FELT                 : -0.0202
#    6 : -0.1027 : gold_answer=         LAW SOCIETY vs LAW SOCIETY          : -0.0306
#    7 : -0.0186 : gold_answer=             TRAFFIC vs TRAFFIC              : -0.0186
#    8 : -0.1645 : gold_answer=              FEELER vs MOTION               : -0.0212
#    9 : -0.0738 : gold_answer=                 DOE vs DOT                  : -0.0263
#   10 : -0.0996 : gold_answer=               REPEL vs REBUT                : -0.0079
#   11 : -0.1545 : gold_answer=                PANT vs SLAP                 : -0.0021
#   12 : -0.0600 : gold_answer=            CHARTRES vs BALMORAL             : -0.0011
#   13 : -0.1288 : gold_answer=            VOCALIST vs YODELLER             : -0.0498
#   14 : -0.0720 : gold_answer=            TROLLING vs RESONANT             : -0.0025
#   15 : -0.2150 : gold_answer=           INJUSTICE vs SWEETENER            : -0.0530
#   16 : -0.0537 : gold_answer=              HOBBLE vs HAMPER               : -0.0290
#   17 : -0.2120 : gold_answer=       ANNE HATHAWAY vs LADY GOODYEAR        : -0.0826
#   18 : -0.0048 : gold_answer=         IN THE PINK vs IN THE PINK          : -0.0048
#   19 : -0.0170 : gold_answer=             UNSCREW vs UNWINDS              : -0.0384
#   20 : -0.0054 : gold_answer=                RIDE vs EXIT                 : -0.0016
#   21 : -0.0526 : gold_answer=              EDITOR vs TIPTOP               : -0.0135
#   22 : -0.0758 : gold_answer=               JABOT vs NERVE                : -0.0376
#   23 : -0.0221 : gold_answer=               IONIC vs IONIC                : -0.0221
#   24 : -0.0127 : gold_answer=               GREED vs ERROR                : -0.0142
#   25 : -0.3378 : gold_answer=                SMOG vs ROOM                 : -0.0078
#   26 : -0.0056 : gold_answer=                NOUS vs TONE                 : -0.0227
#   27 : -0.2176 : gold_answer=           MAIN ROAD vs BUSH CAMP            : -0.0441
#   28 : -0.1143 : gold_answer=               NEVIS vs CAPRI                : -0.0575
#   29 : -0.0766 : gold_answer=           TAX HAVEN vs MID OCEAN            : -0.0184
#   30 : -0.0181 : gold_answer=            ON GUARD vs GO UNDER             : -0.0051
#   31 : -0.0162 : gold_answer=               ORBIT vs INIGO                : -0.0073
#   32 : -0.2193 : gold_answer=             SOUPCON vs LAGGARD              : -0.0295
#   33 : -0.0056 : gold_answer=             BOREDOM vs TWADDLE              : -0.0259
#   34 : -0.2069 : gold_answer=           ANTARCTIC vs GREENLAND            : -0.0096
#   35 : -0.0428 : gold_answer=             SQUEEZE vs LACTATE              : -0.0381
#   36 : -0.0860 : gold_answer=               HELOT vs PETER                : -0.0358
#   37 : -0.0493 : gold_answer=        OSTENTATIOUS vs UNDIPLOMATIC         : -0.0338
#   38 : -0.1769 : gold_answer=               SPEND vs MOPED                : -0.0014
#   39 : -0.0089 : gold_answer=              RESORT vs RESORT               : -0.0089
#   40 : -0.3537 : gold_answer=             HAT PEG vs NAP NAP              : -0.0187
#   41 : -0.0826 : gold_answer=             TRAFFIC vs CONGEAL              : -0.0047
#   42 : -0.0005 : gold_answer=              SEXPOT vs BOMBER               : -0.0070
#   43 : -0.2303 : gold_answer=              CARING vs CARTEL               : -0.0569
#   44 : -0.1160 : gold_answer=         MILLIONAIRE vs PLANTAGENET          : -0.0707
#   45 : -0.0057 : gold_answer=            SUNDRIES vs SUNDRIES             : -0.0057
#   46 : -0.0321 : gold_answer=          CEREMONIAL vs CEREMONIAL           : -0.0321
#   47 : -0.0113 : gold_answer=               LADLE vs ROWER                : -0.0293
#   48 : -0.1013 : gold_answer=               ROWDY vs THONG                : -0.0347
#   49 : -0.0941 : gold_answer=           EDELWEISS vs ANCHORAGE            : -0.0282
#   50 : -0.3589 : gold_answer=        FIDDLESTICKS vs PREPOSTEROUS         : -0.0282
#   51 : -0.0643 : gold_answer=           SAFFLOWER vs HAREBELLS            : -0.0158
#   52 : -0.0347 : gold_answer=             YANGTZE vs KICKASS              : -0.0296
#   53 : -0.2732 : gold_answer=             CENSURE vs MUSTARD              : -0.0147
#   54 : -0.0336 : gold_answer=            GANYMEDE vs MENELAUS             : -0.0273
#   55 : -0.0742 : gold_answer=                AFAR vs AFAR                 : -0.0276
#   56 : -0.2937 : gold_answer=              HAROLD vs THWART               : -0.0275
#   57 : -0.1933 : gold_answer=                ZOOM vs HEEL                 : -0.0376
#   58 : -0.1574 : gold_answer=        CONGLOMERATE vs METROPOLITAN         : -0.0160
#   59 : -0.0063 : gold_answer=           STRAINING vs STRETCHES            : -0.0163
#   60 : -0.1348 : gold_answer=             WITH IT vs CHIP ON              : -0.0178
#   61 : -0.0260 : gold_answer=             TRAFFIC vs LETTERS              : -0.0156
#   62 : -0.1751 : gold_answer=            PREPARED vs PREDATED             : -0.0136
#   63 : -0.0405 : gold_answer=         BLOODY MARY vs ABSENT MIND          : -0.0123
#   64 : -0.0058 : gold_answer=          A DIM VIEW vs A BAD NAME           : -0.0017
#   65 : -0.0939 : gold_answer=            DWARFISH vs DIMINISH             : -0.0130
#   66 : -0.0126 : gold_answer=         BLOODY MARY vs RUSSIA CASK          : -0.0086
#   67 : -0.0937 : gold_answer=           PERSIMMON vs PERCHANCE            : -0.0393
#   68 : -0.0488 : gold_answer=         MILLIONAIRE vs PLANTAGENET          : -0.0325
#   69 : -0.2473 : gold_answer=       STARTING GATE vs HURDLING RACE        : -0.0085
#   70 : -0.0061 : gold_answer=          KETTLEDRUM vs WINDCHIMES           : -0.0034
#   71 : -0.1178 : gold_answer=          POLYANTHUS vs POLYANTHUS           : -0.0252
#   72 : -0.0830 : gold_answer=                PATH vs PAVE                 : -0.0118
#   73 : -0.0885 : gold_answer=          ATTAINMENT vs DEPLORABLE           : -0.0005
#   74 : -0.0851 : gold_answer=                PULP vs MASH                 : -0.0166
#   75 : -0.0762 : gold_answer=    GOLDEN PARACHUTE vs DOUBLE CHECKBOOK     : -0.0043
#   76 : -0.1422 : gold_answer=              VENIAL vs PIGEON               : -0.0018
#   77 : -0.0128 : gold_answer=            PREAMBLE vs PREAMBLE             : -0.0128
#   78 : -0.0260 : gold_answer=          PALINDROME vs RACKETEERS           : -0.0012
#   79 : -0.0898 : gold_answer=        ARITHMETICAL vs ARITHMETICAL         : -0.0067
#   80 : -0.0584 : gold_answer=            TEAMSTER vs TEARAWAY             : -0.0101
#   81 : -0.0347 : gold_answer=            APTITUDE vs TALENTED             : -0.0182
#   82 : -0.0226 : gold_answer=           FOLKLORIC vs TRIBELESS            : -0.0019
#   83 : -0.0580 : gold_answer=               TACOS vs TACOS                : -0.0251
#   84 : -0.1298 : gold_answer=           ADJECTIVE vs NIGHTSPOT            : -0.0057
#   85 : -0.0012 : gold_answer=              WIDGET vs WHEELS               : -0.0020
#   86 : -0.1503 : gold_answer=              FRAPPE vs CORKER               : -0.0084
#   87 : -0.0154 : gold_answer=            PARASITE vs PARASITE             : -0.0154
#   88 : -0.0281 : gold_answer=             YELLOWS vs YELLOWS              : -0.0237
#   89 : -0.0560 : gold_answer=                THIN vs POOR                 : -0.0332
#   90 : -0.1024 : gold_answer= NOUGHTS AND CROSSES vs PASSIVE AND PASSIVE  : -0.0314
#   91 : -0.0113 : gold_answer=          MONOCHROME vs MONOCHROME           : -0.0113
#   92 : -0.1826 : gold_answer=             SPOUTED vs RANCHED              : -0.0113
#   93 : -0.0387 : gold_answer=         DARTH VADER vs DRIFT VOTER          : -0.0003
#   94 : -0.0797 : gold_answer=           SWINEHERD vs THRESHING            : -0.0298
#   95 : -0.0772 : gold_answer=           BRUSH OFF vs KNOCK OFF            : -0.0018
#   96 : -0.1331 : gold_answer=               ORRIS vs TULIP                : -0.0112
#   97 : -0.0019 : gold_answer=              CATERS vs CATERS               : -0.0019
#   98 : -0.0127 : gold_answer=                EATS vs BATS                 : -0.0084
#   99 : -0.4497 : gold_answer=                PEAL vs OHMS                 : -0.0270
#  100 : -0.1040 : gold_answer=              PLEASE vs PLEASE               : -0.0305
#  101 : -0.0079 : gold_answer=               SIZED vs EXACT                : -0.0047
#  102 : -0.0031 : gold_answer=         FLIGHT DECK vs STAIRS CASE          : -0.0010
#  103 : -0.0646 : gold_answer=              LACKEY vs EXCEED               : -0.0167
#  104 : -0.0968 : gold_answer=           CURTILAGE vs ROCKERIES            : -0.0413
#  105 : -0.0033 : gold_answer=                SASH vs SASH                 : -0.0033
#  106 : -0.0067 : gold_answer=            OFFENDER vs OFFENDER             : -0.0067
#  107 : -0.0419 : gold_answer=              DOTAGE vs TWILIT               : -0.0036
#  108 : -0.0631 : gold_answer=               CUBIT vs NIPPY                : -0.0159
#  109 : -0.0937 : gold_answer=              LOOTER vs NIMROD               : -0.0119
#  110 : -0.1680 : gold_answer=            PLAYBILL vs BILLOWED             : -0.0313
#  111 : -0.0883 : gold_answer=              SNICKS vs SPARKS               : -0.0070
#  112 : -0.0014 : gold_answer=               DROLL vs DROLL                : -0.0014
#  113 : -0.0328 : gold_answer=          OLD STAGER vs ALL AROUND           : -0.0154
#  114 : -0.0301 : gold_answer=               SERUM vs SERUM                : -0.0301
#  115 : -0.0215 : gold_answer=             MAILLOT vs LEGHORN              : -0.0181
#  116 : -0.2337 : gold_answer=                TUNA vs GUTS                 : -0.0159
#  117 : -0.0849 : gold_answer=           TRIALOGUE vs TRIANGLED            : -0.0371
#  118 : -0.0377 : gold_answer=          TERMINATOR vs TERMINATOR           : -0.0221
#  119 : -0.0077 : gold_answer=            ORNATELY vs ORNATELY             : -0.0077
#  120 : -0.0413 : gold_answer=                ARIA vs LULU                 : -0.0394
#  121 : -0.1017 : gold_answer=      SITTING PRETTY vs CHICKEN DINNER       : -0.0306
#  122 : -0.0280 : gold_answer=        OUT OF SORTS vs OUT OF REACH         : -0.0011
#  123 : -0.0309 : gold_answer=           DENIGRATE vs DISSERVED            : -0.0133
#  124 : -0.1673 : gold_answer=               SABOT vs SNEAK                : -0.0071
#  125 : -0.1153 : gold_answer=        CALL WAITING vs CLAP STRETCH         : -0.0145
#  126 : -0.0003 : gold_answer=            GUNSMITH vs GUNSMITH             : -0.0003
#  127 : -0.0747 : gold_answer=            LA SCALA vs LA SCALA             : -0.0301
#  128 : -0.0051 : gold_answer=                IOTA vs INCH                 : -0.0095
#  129 : -0.0911 : gold_answer=            ILL FAME vs LOW FIVE             : -0.0273
#  130 : -0.2004 : gold_answer=           ORCHESTRA vs ORCHESTRA            : -0.0312
#  131 : -0.0588 : gold_answer=           LOATHSOME vs LECHEROUS            : -0.0043
#  132 : -0.0007 : gold_answer=            TASTEFUL vs SUITABLE             : -0.0018
#  133 : -0.1293 : gold_answer=            DIAMETER vs DISTRACT             : -0.0075
#  134 : -0.0861 : gold_answer=           SYNTHETIC vs SHAMBLING            : -0.0173
#  135 : -0.0039 : gold_answer=             PERUSAL vs SCANNER              : -0.0019
#  136 : -0.0014 : gold_answer=             INFERNO vs NOISOME              : -0.0089
#  137 : -0.1093 : gold_answer=               ANNUL vs ANNUL                : -0.0649
#  138 : -0.2181 : gold_answer=            SCROUNGE vs DISARMED             : -0.0408
#  139 : -0.1743 : gold_answer=           LINGERING vs LINGERING            : -0.0028
#  140 : -0.1735 : gold_answer=               ROACH vs CARPI                : -0.0128
#  141 : -0.1412 : gold_answer=            CASSETTE vs PRESERVE             : -0.0146
#  142 : -0.0105 : gold_answer=              INNATE vs CATTLE               : -0.0080
#  143 : -0.1382 : gold_answer=             SPECKLE vs PIGGISH              : -0.0094
#  144 : -0.0761 : gold_answer=       COWARDLY LION vs CHERWELL BLUE        : -0.0027
#  145 : -0.0192 : gold_answer=      SITTING PRETTY vs SITTING PRETTY       : -0.0192
#  146 : -0.0865 : gold_answer=          EAU DE NIL vs LIE TO SEE           : -0.0019
#  147 : -0.1208 : gold_answer=             SADNESS vs SATIRES              : -0.0296
#  148 : -0.0384 : gold_answer=         GROUNDSWELL vs OPINIONATED          : -0.0031
#  149 : -0.0347 : gold_answer=             DRESSED vs DRESSED              : -0.0347
#  150 : -0.0369 : gold_answer=           FROSTBITE vs ROUGHNESS            : -0.0118
#  151 : -0.0134 : gold_answer=             ORBITER vs ORBITER              : -0.0134
#  152 : -0.0164 : gold_answer=                BAND vs BARD                 : -0.0124
#  153 : -0.0086 : gold_answer=          FORTRESSES vs FORTRESSES           : -0.0086
#  154 : -0.1263 : gold_answer=          PERSIFLAGE vs ORIGINALLY           : -0.0196
#  155 : -0.1251 : gold_answer=            OVERTURN vs EXTREMES             : -0.0104
#  156 : -0.0146 : gold_answer=              TROWEL vs WEEDER               : -0.0123
#  157 : -0.1615 : gold_answer=              RIDDLE vs JIGSAW               : -0.0111
#  158 : -0.0082 : gold_answer=       AGONY COLUMNS vs YOUNG GLAMOUR        : -0.0131
#  159 : -0.0341 : gold_answer=         THIRD PARTY vs CHIEF AGENT          : -0.0073
#  160 : -0.0179 : gold_answer=               IOWAN vs OSAGE                : -0.0144
#  161 : -0.0482 : gold_answer=           MAINTAINS vs MAINTAINS            : -0.0265
#  162 : -0.0417 : gold_answer=             CYPRESS vs TIMBERS              : -0.0499
#  163 : -0.0155 : gold_answer=                DASH vs CRAM                 : -0.0039
#  164 : -0.0182 : gold_answer=                GLUT vs GLUT                 : -0.0182
#  165 : -0.1771 : gold_answer=                PANT vs YARN                 : -0.0037
#  166 : -0.1550 : gold_answer=         CAT AND DOG vs RAT AND CAT          : -0.0527
#  167 : -0.0329 : gold_answer=             SEE OFF vs GET OFF              : -0.0089
#  168 : -0.0559 : gold_answer=         GRAVEDIGGER vs GALLOWGLASS          : -0.0208
#  169 : -0.1443 : gold_answer=               NOTCH vs PANDA                : -0.0334
#  170 : -0.0143 : gold_answer=           METACARPI vs REACHABLE            : -0.0298
#  171 : -0.0247 : gold_answer=           ORCHESTRA vs CRITERION            : -0.0226
#  172 : -0.1156 : gold_answer=                 EWE vs HEW                  : -0.0099
#  173 : -0.0573 : gold_answer=        GO ON RECORD vs ON ON RECORD         : -0.0020
#  174 : -0.1078 : gold_answer=               SPREE vs TWEED                : -0.0684
#  175 : -0.0002 : gold_answer=        DOUBLE CROSS vs DOUBLE CROSS         : -0.0002
#  176 : -0.1594 : gold_answer=           COIFFEUSE vs LAUGHABLE            : -0.0833
#  177 : -0.0104 : gold_answer=      DANIEL DERONDA vs DANIEL DERONDA       : -0.0104
#  178 : -0.0883 : gold_answer=          CONSCIENCE vs CONSISTENT           : -0.0187
#  179 : -0.0851 : gold_answer=             LUCIFER vs UNITING              : -0.0185
#  180 : -0.0134 : gold_answer=          CONFISCATE vs DISPOSSESS           : -0.0092
#  181 : -0.0690 : gold_answer=              STRAIN vs ACCENT               : -0.0434
#  182 : -0.2895 : gold_answer=                FINN vs ABET                 : -0.0400
#  183 : -0.3444 : gold_answer=          JINGOISTIC vs JABBERWOCK           : -0.0206
#  184 : -0.2719 : gold_answer=            RETAINER vs PRESERVE             : -0.0289
#  185 : -0.0752 : gold_answer=             GLUTTON vs GLUTTON              : -0.0336
#  186 : -0.1602 : gold_answer=         SKIN DIVING vs POLO SHIRTS          : -0.0232
#  187 : -0.0194 : gold_answer=              REASON vs REPAIR               : -0.0141
#  188 : -0.0180 : gold_answer=             FORBEAR vs BEARISH              : -0.0045
#  189 : -0.0259 : gold_answer=               BESET vs LEASH                : -0.0232
#  190 : -0.0846 : gold_answer=      FUTURE PERFECT vs FUTURE PERFECT       : -0.0846
#  191 : -0.0120 : gold_answer=           GAME BIRD vs GAME BIRD            : -0.0120
#  192 : -0.0644 : gold_answer=               HELOT vs TILLS                : -0.0365
#  193 : -0.0031 : gold_answer=                TOSS vs TOSS                 : -0.0031
#  194 : -0.0172 : gold_answer=             ISRAELI vs PEASANT              : -0.0079
#  195 : -0.2160 : gold_answer=               LLAMA vs TAMIL                : -0.0290
#  196 : -0.1557 : gold_answer=          PALMERSTON vs PALMERSTON           : -0.0875
#  197 : -0.0017 : gold_answer=            GIVE OFF vs PLAY OFF             : -0.0082
#  198 : -0.1214 : gold_answer=               SUNUP vs RISEN                : -0.0221
#  199 : -0.1386 : gold_answer=       RAPPROCHEMENT vs CONVALESCENCE        : -0.0427
# Overall :   41/ 200 correct=20.50%
#   Quick :    7/  15 correct=46.67%
#    Hard :   34/ 185 correct=18.38%
# (41, 200)

# %% [markdown]
# ## Do-over prompting : Could this work?

# %%
import solver

overlaid = solver.dataset.read_log_results([
  './experiments/wordplay/._llama3-it_def_and_wordplay_guesser_4_epoch_noex/test_2024-09-17_15-36-50.log',
],)

# %%
def find_gold(question_wordplay_arr):
  for wordplay_example in question_wordplay_arr:
    if wordplay_example['is_gold']:
      #return wordplay_example['answer'] # Should also have freq in it..
      freq = wordplay_example.get('freq', 0 if wordplay_example['answer_gold_added'] else 1)
      return wordplay_example['answer'], freq

question_idx=2
question_wordplay_arr = overlaid[question_idx]
answer_gold, gold_freq = find_gold( question_wordplay_arr )
#answer_gold, gold_freq

for wordplay_example in question_wordplay_arr:
  print(f"{'**GOLD**  ' if wordplay_example['is_gold'] else ''}answer: {wordplay_example['answer']}")
  print(f"  definition: {wordplay_example['clue_with_def']}")
  print(f"  wordplay:   {wordplay_example['wordplay']}")
# Out:
# answer: ACCEPTS
#   definition: {puzzles} full of holes?
#   wordplay:   ACCEPTS (full of holes)
# answer: ACCEPTS
#   definition: {puzzles} full of holes?
#   wordplay:   ACCEPTS (full of holes)
# answer: ACCEPTS
#   definition: {puzzles} full of holes?
#   wordplay:   ACCEPTS (full of holes)
# answer: ACCEPTS
#   definition: {puzzles} full of holes?
#   wordplay:   ACCEPTS (full of holes)
# answer: ACCEPTS
#   definition: {puzzles} full of holes?
#   wordplay:   ACCEPTS (full of holes)
# answer: GRIDDLE
#   definition: {puzzles} full of holes?
#   wordplay:   GRIDDLES (full of holes)
# answer: GRIDDLE
#   definition: {puzzles} full of holes?
#   wordplay:   GRIDDLES (full of holes)
# answer: GRIDDLE
#   definition: {puzzles} full of holes?
#   wordplay:   GRIDS (full of holes)
# answer: GRIDDLE
#   definition: {puzzles} full of holes?
#   wordplay:   GRIDDLE (full of holes)
# answer: GRIDDLE
#   definition: {puzzles} full of holes?
#   wordplay:   GRIDDLES (full of holes)
# answer: JIGSAWS
#   definition: {puzzles} full of holes?
#   wordplay:   JIGS (full of holes) + AWS (puzzles)
# answer: JIGSAWS
#   definition: {puzzles} full of holes?
#   wordplay:   JIGS (full of holes) + AWS (puzzles)
# answer: JIGSAWS
#   definition: {puzzles} full of holes?
#   wordplay:   JIGS (full of holes) + AWS (puzzles)
# answer: JIGSAWS
#   definition: {puzzles} full of holes?
#   wordplay:   Cryptic definition
# answer: JIGSAWS
#   definition: {puzzles} full of holes?
#   wordplay:   Cryptic definition
# answer: REBUSES
#   definition: {puzzles} full of holes?
#   wordplay:   RE (full of) + BUSES (holes)
# answer: REBUSES
#   definition: {puzzles} full of holes?
#   wordplay:   [h]OB[les] (full of)
# answer: REBUSES
#   definition: {puzzles} full of holes?
#   wordplay:   RE (full of) + BUSES (holes)
# answer: REBUSES
#   definition: {puzzles} full of holes?
#   wordplay:   [h]OBLES (full of holes)
# answer: REBUSES
#   definition: {puzzles} full of holes?
#   wordplay:   RE (full of) + B[r]U[s]E[s] (holes)
# **GOLD**  answer: RIDDLES
#   definition: {puzzles} full of holes?
#   wordplay:   RIDDLES full of H (holes)
# **GOLD**  answer: RIDDLES
#   definition: {puzzles} full of holes?
#   wordplay:   RIDDLES full of H (holes)
# **GOLD**  answer: RIDDLES
#   definition: {puzzles} full of holes?
#   wordplay:   RIDDLES (full of holes)
# **GOLD**  answer: RIDDLES
#   definition: {puzzles} full of holes?
#   wordplay:   RIDDLES full of H (holes)
# **GOLD**  answer: RIDDLES
#   definition: {puzzles} full of holes?
#   wordplay:   RIDDLES full of H (holes)
# answer: STUMBLE
#   definition: {puzzles} full of holes?
#   wordplay:   STUMBLES (full of holes)
# answer: STUMBLE
#   definition: {puzzles} full of holes?
#   wordplay:   STUMBLES (full of holes)
# answer: STUMBLE
#   definition: {puzzles} full of holes?
#   wordplay:   STUMBLES (full of holes)
# answer: STUMBLE
#   definition: {puzzles} full of holes?
#   wordplay:   STUMBLE is a golf term, full of holes
# answer: STUMBLE
#   definition: {puzzles} full of holes?
#   wordplay:   STUMBLE is a type of puzzle
# answer: STUMIES
#   definition: {puzzles} full of holes?
#   wordplay:   full of STUMPS (holes)
# answer: STUMIES
#   definition: {puzzles} full of holes?
#   wordplay:   STUMBLE (full of holes)
# answer: STUMIES
#   definition: {puzzles} full of holes?
#   wordplay:   STUMBLE (full of holes)
# answer: STUMIES
#   definition: {puzzles} full of holes?
#   wordplay:   Cryptic definition
# answer: STUMIES
#   definition: {puzzles} full of holes?
#   wordplay:   Cryptic definition
# answer: STUMOES
#   definition: {puzzles} full of holes?
#   wordplay:   (FULL OF HOLES)* (*puzzles)
# answer: STUMOES
#   definition: {puzzles} full of holes?
#   wordplay:   STUMPS (full of holes)
# answer: STUMOES
#   definition: {puzzles} full of holes?
#   wordplay:   STUMBLE (full of holes)
# answer: STUMOES
#   definition: {puzzles} full of holes?
#   wordplay:   (MOLES)* (*full of holes)
# answer: STUMOES
#   definition: {puzzles} full of holes?
#   wordplay:   STUMBLE (full of holes)
# answer: STUMPED
#   definition: {puzzles} full of holes?
#   wordplay:   ST (full of) + UMPED (holes)
# answer: STUMPED
#   definition: {puzzles full of holes}?
#   wordplay:   Cryptic definition
# answer: STUMPED
#   definition: {puzzles full of holes}?
#   wordplay:   Cryptic definition
# answer: STUMPED
#   definition: {puzzles} full of holes?
#   wordplay:   STUM[p]ED (full of holes)
# answer: STUMPED
#   definition: {puzzles full of holes}?
#   wordplay:   Cryptic definition
# answer: STYMIES
#   definition: {puzzles} full of holes?
#   wordplay:   STY (full of) + MIES (holes)
# answer: STYMIES
#   definition: {puzzles} full of holes?
#   wordplay:   ST (full of) + Y (holes) + MIES (puzzles)
# answer: STYMIES
#   definition: {puzzles} full of holes?
#   wordplay:   Cryptic definition
# answer: STYMIES
#   definition: {puzzles} full of holes?
#   wordplay:   Cryptic definition
# answer: STYMIES
#   definition: {puzzles} full of holes?
#   wordplay:   Cryptic definition
# answer: TEASERS
#   definition: {puzzles} full of holes?
#   wordplay:   [h]TEASERS (full of holes)
# answer: TEASERS
#   definition: {puzzles} full of holes?
#   wordplay:   TEA (full of) + S[ho]E[s] (holes)
# answer: TEASERS
#   definition: {puzzles} full of holes?
#   wordplay:   TEASERS (full of holes)
# answer: TEASERS
#   definition: {puzzles} full of holes?
#   wordplay:   TEA (full of holes) + SERS (full)
# answer: TEASERS
#   definition: {puzzles} full of holes?
#   wordplay:   TEA (full of holes, as in a tea infuser) + SERS (puzzles)

# %%
question_wordplay_arr[0]
# Out:
# {'answer': 'ABLOOMY',
#  'answer_gold_added': False,
#  'clue': 'one may have special tie on - - a nob, ob standing out?',
#  'clue_with_def': '{one may have special tie on} - - a nob, ob standing out?',
#  'is_gold': False,
#  'pattern': '7',
#  'wordplay': 'A BOOM (a nob, ob standing out)',
#  'idx_orig': 8117}
